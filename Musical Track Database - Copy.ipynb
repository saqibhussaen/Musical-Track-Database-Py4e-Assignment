# %%
import sqlite3

#Connet makes a new file if not available
conn = sqlite3.connect('y:/py4e notebooks/MusicalTrackDatabasetest10.sqlite')
cur = conn.cursor()

cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Genre (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    genre_id  INTEGER,
    len INTEGER,
    rating INTEGER,
    count INTEGER
);

''')

# %% [markdown]
# Values I need to store in Database:
#
# Artist
#
# Genre
#
# Album
#
# Track:
#
# id, title, album_id, genre_id, len, rating, count

# %%
import xml.etree.ElementTree as ET

handle = ET.parse('y:/Py4e Notebooks/Library.xml')
all = handle.findall('dict/dict/dict')
print ("Track Count:", len(all))
# Out:
# Track Count: 404

# %%
def lookup(d, key):
    found = False
    for child in d:
        if found :
            return child.text
        if child.tag == 'key' and child.text == key :
            found = True
    return None

for entry in all:
    if ( lookup(entry, 'Track ID') is None ) : continue

    name = lookup(entry, 'Name')
    count = lookup(entry, 'Play Count')
    rating = lookup(entry, 'Rating')
    length = lookup(entry, 'Total Time')
    artist = lookup(entry, 'Artist')
    album = lookup(entry, 'Album')
    genre = lookup(entry, 'Genre')
    track = lookup(entry, 'Track')

    if name is None or artist is None or album is None or genre is None : 
        continue

    print(artist, album, genre, track)

    cur.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cur.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cur.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Genre (name) 
        VALUES ( ? )''', ( genre, ) )
    cur.execute('SELECT id FROM Genre WHERE name = ? ', (genre, ))
    genre_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, genre_id, len, rating, count) 
        VALUES ( ?, ?, ?, ?, ?, ? )''', 
        ( name, album_id, genre_id, length, rating, count ) )
    
conn.commit()
# Out:
# Queen Greatest Hits Rock None
# Rammstein Herzeleid Industrial None
# Various Grease Soundtrack None
# Led Zeppelin IV Rock None
# Pink Floyd The Wall [Disc 2] Rock None
# Bryan Lee Blues Is Funk None
# Pink Floyd The Wall [Disc 2] Rock None
# Queen Greatest Hits Rock None
# Black Sabbath Paranoid Metal None
# Queen Greatest Hits Rock None
# AC/DC Who Made Who Rock None
# Led Zeppelin IV Rock None
# Rob Dougan The Matrix Reloaded Soundtrack None
# Bryan Lee Blues Is Blues/R&B None
# Led Zeppelin IV Rock None
# Various Grease Soundtrack None
# Black Sabbath Paranoid Metal None
# AC/DC Who Made Who Rock None
# Pink Floyd The Wall [Disc 2] Rock None
# Bryan Lee Blues Is Blues/R&B None
# Black Sabbath Paranoid Metal None
# Pink Floyd The Wall [Disc 2] Rock None
# Frank Sinatra Greatest Hits Easy Listening None
# Bryan Lee Blues Is Blues/R&B None
# Black Sabbath Paranoid Metal None
# Queen Greatest Hits Rock None
# Rammstein Herzeleid Industrial None
# Bryan Lee Blues Is Blues/R&B None
# ...

# %% [markdown]
# Track: id, title, album_id, genre_id, len, rating, count
#
# name = lookup(entry, 'Name')
# artist = lookup(entry, 'Artist')
# album = lookup(entry, 'Album')
# count = lookup(entry, 'Play Count')
# rating = lookup(entry, 'Rating')
# length = lookup(entry, 'Total Time')
